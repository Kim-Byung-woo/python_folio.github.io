# %% [markdown]
# # 1. 파이썬 자료형

# %% [markdown]
# ## 1-2. list

# %% [markdown]
# #### **리스트 인덱싱**

# %%
a = [1,2,3]
print(a[0]) # a[0]은 리스트 a의 첫 번째 요솟값
print(a[0] + a[1])
print(a[-1])
print(a[3]) # 인덱스 Error
# Out:
# 1
# 3
# 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-e3e0076bca70> in <module>
#       3 print(a[0] + a[1])
#       4 print(a[-1])
# ----> 5 print(a[3]) # 인덱스 Error
#
# IndexError: list index out of range

# %% [markdown]
# #### **이중 리스트**

# %%
a = [1,2,3, ['a','b','c']]
print(a[3])
print(a[3][1])
# Out:
# ['a', 'b', 'c']
# b

# %% [markdown]
# ## **리스트 슬라이싱**

# %%
a = [1,2,3,4,5]
a[0:2]
# Out:
# [1, 2]

# %%
b = a[:2]
print(b)
# Out:
# [1, 2]

# %%
c = a[2:]
print(c)
# Out:
# [3, 4, 5]

# %%
a = [1, 2, 3, ['a', 'b', 'c'], 4, 5]
a[2:5]
# Out:
# [3, ['a', 'b', 'c'], 4]

# %%
a[3][:2]
# Out:
# ['a', 'b']

# %%
b = a[1:3]
b
# Out:
# [2, 3]

# %%
b.append(a[3][0:2])
c = []
c=b
c
# Out:
# [2, 3, ['a', 'b']]

# %%
b = b.append(a[3][0:2]) # append함수는 리턴값이 없기 때문에 바로 대입이 안됩니다.
print(b)
# Out:
# None

# %% [markdown]
# #### **리스트 길이 구하기**

# %%
b = [1, 3, 5]
print(len(b))
# Out:
# 3

# %% [markdown]
# #### **리스트 추가**

# %%
a = [1, 2, 3]
a.insert(0, 4) #insert(a, b): 리스트의 a번째 위치에 b를 삽입하는 함수
print(a)
# Out:
# [4, 1, 2, 3]

# %%
a = [1,2,3]
a.extend([4,5]) # extend는 요소만 추가 됩니다.
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
b = [1,2,3]
b.append([4,5]) # append는 리스트 자체가 추가
print(b)
# Out:
# [1, 2, 3, [4, 5]]

# %% [markdown]
# #### **리스트 수정**

# %%
a = [2,4,6]
a[1] = 8 
print(a)
# Out:
# [2, 8, 6]

# %% [markdown]
# #### **리스트 삭제**

# %%
a = [2, 4, 6]
del a[2]
print(a)
# Out:
# [2, 4]

# %%
a = [1,2,3, 1,2,3]
a.remove(2) #remove: 첫번째로 나온 요소를 삭제합니다.
print(a)
# Out:
# [1, 3, 1, 2, 3]

# %%
a = [1, 2, 3]
a.pop() #리스트의 맨 마지막 요소를 돌려주고 그 요소는 삭제한다
print(a)
# Out:
# [1, 2]

# %% [markdown]
# #### **리스트 정렬**

# %%
a = [1, 4, 3, 2]
a.sort() # 오름정렬
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a.reverse() # 내림정렬
print(a)
# Out:
# [4, 3, 2, 1]

# %%
a = [1,4, 3, 2]
a.sort(reverse = True) # 내림정렬
print(a)
# Out:
# [4, 3, 2, 1]

# %% [markdown]
# #### **count(x)는 리스트 안에 x가 몇 개 있는지 조사하여 그 개수를 돌려주는 함수이다.**

# %%
a = [1,2,3,1]
a.count(1)
# Out:
# 2
